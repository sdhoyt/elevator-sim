# %%
import elevator

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
elev = elevator.Elevator()

out = elev.go_to_floor([2], real_time=False)
out
# Out:
#     time_elapsed  current_floor  floors_to_next_dest  time_to_next_dest  \
# 0              0              1                    1                 10
# 1              1              1                    1                  9
# 2              2              1                    1                  8
# 3              3              1                    1                  7
# 4              4              1                    1                  6
# 5              5              1                    1                  5
# 6              6              1                    1                  4
# 7              7              1                    1                  3
# 8              8              1                    1                  2
# 9              9              1                    1                  1
# 10            10              2                 <NA>               <NA>
#
#     next_destination
# 0                  2
# 1                  2
# 2                  2
# ...
