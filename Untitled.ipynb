# %%
import elevator
import pandas as pd

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
elev = elevator.Elevator(5)

out = elev.go_to_floor([2, 4], real_time=False)

# %%
out
# Out:
#     time_elapsed  current_floor  floors_to_next_dest  time_to_next_dest  \
# 0              0              5                    3               30.0
# 1              1              5                    3               29.0
# 2              2              5                    3               28.0
# 3              3              5                    3               27.0
# 4              4              5                    3               26.0
# 5              5              5                    3               25.0
# 6              6              5                    3               24.0
# 7              7              5                    3               23.0
# 8              8              5                    3               22.0
# 9              9              5                    3               21.0
# 10            10              4                    2               20.0
# 11            11              4                    2               19.0
# ...
